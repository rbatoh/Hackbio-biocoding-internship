# %% [markdown]
# <a href="https://colab.research.google.com/github/lauramazzu/hackbio-biocoding-internship/blob/main/Hackbio_Task_2_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task** **Code 2.4**:
# **Biochemistry & Oncology **
# Proteins structures are known to be strongly connected to their functions. However, at the amino acid level, not all amino acids contribute to structure and function equally. Galardini and colleagues decided to investigate the impact of all possible individual, non synonymous nonsense mutations on the structure and function of protein.
#
# The functional impact was computed as SIFT scores and the structural impact was calculated as FoldX Score (in kCal/mol).
#
# Dataset Here:
# SIFT Dataset
# FoldX Dataset
#
# Task
# Import both sift and foldx datasets; in both datasets, create a column specific_Protein_aa which will be a cantenation of the Protein and Amino_acid columns such that If you have Protein A5A607 and Amino_acid E63D, you have specific_Protein_aa A5A607_E63D
#
# Using the specific_Protein_aa column, merge sift and foldx dataset into one final dataframe.
#
# According to the authors;
# A SIFT Score below 0.05 is deleterious
# A FoldX score greater than 2 kCal/mol is deleterious
#
# Using the criteria above, Find all mutations that have a SIFT score below 0.05 and FoldX Score above 2 (i.e: Mutations that affect both structure and function)
# Study the amino acid substitution nomenclature
#
# Investigate for the amino acid that has the most functional and structural impact
#
# Hint: Using the amino acid column, find a way to select the first amino acid. Solution here
#
# Generate a frequency table for all the amino acids
#
# Using the amino frequency table above, generate a barplot and pie chart to represent the frequency of the amino acids.
#
# Briefly describe the amino acid with the highest impact on protein structure and function
#
# What can you say about the structural property and functional property of amino acids with more than 100 occurences.

# %%
#importing
import pandas as pd

import plotly.express as px
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
#opening the dataset
from posixpath import sep
sift_file_url = "https://raw.githubusercontent.com/HackBio-Internship/public_datasets/main/R/datasets/sift.tsv"
sift_df = pd.read_csv(sift_file_url, sep = "\s+", engine = "python")
sift_df
# Out:
#        Protein Amino_Acid  sift_Score
# 0       A5A607       K60Q    0.197799
# 1       A5A607       Y56C    0.174970
# 2       A5A607       Y56S    0.415581
# 3       A5A630       A16V    0.516738
# 4       A5A630       A47T    0.387271
# ...        ...        ...         ...
# 155462  Q93K97      S190P    0.017680
# 155463  Q93K97      T124I    0.169846
# 155464  Q93K97       T23I    0.094208
# 155465  Q93K97      V145L    1.000000
# 155466  Q93K97       V49I    0.740893
#
# [155467 rows x 3 columns]

# %%
#opening the other dataset
foldx_file_url = "https://raw.githubusercontent.com/HackBio-Internship/public_datasets/main/R/datasets/foldX.tsv"
foldx_df = pd.read_csv(foldx_file_url, sep = '\s+', engine = "python")
foldx_df
# Out:
#       Protein Amino_Acid  foldX_Score
# 0      A5A607       E63D     1.842160
# 1      A5A607       K60Q     0.517100
# 2      A5A607       Y56C     0.728700
# 3      A5A607       Y56S     0.842120
# 4      P00350      A117S    -0.098540
# ...       ...        ...          ...
# 76570  Q93K97      S190P    -1.778610
# 76571  Q93K97      T124I    -0.973832
# 76572  Q93K97       T23I    -0.242378
# 76573  Q93K97      V145L    -0.249012
# 76574  Q93K97       V49I    -0.381140
#
# [76575 rows x 3 columns]

# %%
#created a new column in sift_df
sift_df["specific_Protein_aa"] = sift_df["Protein"] + "_" + sift_df["Amino_Acid"]
sift_df
# Out:
#        Protein Amino_Acid  sift_Score specific_Protein_aa
# 0       A5A607       K60Q    0.197799         A5A607_K60Q
# 1       A5A607       Y56C    0.174970         A5A607_Y56C
# 2       A5A607       Y56S    0.415581         A5A607_Y56S
# 3       A5A630       A16V    0.516738         A5A630_A16V
# 4       A5A630       A47T    0.387271         A5A630_A47T
# ...        ...        ...         ...                 ...
# 155462  Q93K97      S190P    0.017680        Q93K97_S190P
# 155463  Q93K97      T124I    0.169846        Q93K97_T124I
# 155464  Q93K97       T23I    0.094208         Q93K97_T23I
# 155465  Q93K97      V145L    1.000000        Q93K97_V145L
# 155466  Q93K97       V49I    0.740893         Q93K97_V49I
#
# [155467 rows x 4 columns]

# %%
#created a new column in foldx_df
foldx_df["specific_Protein_aa"] = foldx_df["Protein"] + "_" + foldx_df["Amino_Acid"]
foldx_df
# Out:
#       Protein Amino_Acid  foldX_Score specific_Protein_aa
# 0      A5A607       E63D     1.842160         A5A607_E63D
# 1      A5A607       K60Q     0.517100         A5A607_K60Q
# 2      A5A607       Y56C     0.728700         A5A607_Y56C
# 3      A5A607       Y56S     0.842120         A5A607_Y56S
# 4      P00350      A117S    -0.098540        P00350_A117S
# ...       ...        ...          ...                 ...
# 76570  Q93K97      S190P    -1.778610        Q93K97_S190P
# 76571  Q93K97      T124I    -0.973832        Q93K97_T124I
# 76572  Q93K97       T23I    -0.242378         Q93K97_T23I
# 76573  Q93K97      V145L    -0.249012        Q93K97_V145L
# 76574  Q93K97       V49I    -0.381140         Q93K97_V49I
#
# [76575 rows x 4 columns]

# %%
#Using the specific_Protein_aa column, merge sift and foldx dataset into one final dataframe.

merged_df = pd.merge(sift_df, foldx_df, on = "specific_Protein_aa")
merged_df
# Out:
#       Protein_x Amino_Acid_x  sift_Score specific_Protein_aa Protein_y  \
# 0        A5A607         K60Q    0.197799         A5A607_K60Q    A5A607
# 1        A5A607         Y56C    0.174970         A5A607_Y56C    A5A607
# 2        A5A607         Y56S    0.415581         A5A607_Y56S    A5A607
# 3        P00350        A117S    0.401519        P00350_A117S    P00350
# 4        P00350        A117T    0.282769        P00350_A117T    P00350
# ...         ...          ...         ...                 ...       ...
# 75332    Q93K97        S190P    0.017680        Q93K97_S190P    Q93K97
# 75333    Q93K97        T124I    0.169846        Q93K97_T124I    Q93K97
# 75334    Q93K97         T23I    0.094208         Q93K97_T23I    Q93K97
# 75335    Q93K97        V145L    1.000000        Q93K97_V145L    Q93K97
# 75336    Q93K97         V49I    0.740893         Q93K97_V49I    Q93K97
#
#       Amino_Acid_y  foldX_Score
# 0             K60Q     0.517100
# 1             Y56C     0.728700
# ...

# %%
#eliminate duplicates columns which have the same values, regardless of the column name.
final_df = merged_df.T.drop_duplicates().T
final_df
# Out:
#       Protein_x Amino_Acid_x sift_Score specific_Protein_aa foldX_Score
# 0        A5A607         K60Q   0.197799         A5A607_K60Q      0.5171
# 1        A5A607         Y56C    0.17497         A5A607_Y56C      0.7287
# 2        A5A607         Y56S   0.415581         A5A607_Y56S     0.84212
# 3        P00350        A117S   0.401519        P00350_A117S    -0.09854
# 4        P00350        A117T   0.282769        P00350_A117T     0.92352
# ...         ...          ...        ...                 ...         ...
# 75332    Q93K97        S190P    0.01768        Q93K97_S190P    -1.77861
# 75333    Q93K97        T124I   0.169846        Q93K97_T124I   -0.973832
# 75334    Q93K97         T23I   0.094208         Q93K97_T23I   -0.242378
# 75335    Q93K97        V145L        1.0        Q93K97_V145L   -0.249012
# 75336    Q93K97         V49I   0.740893         Q93K97_V49I    -0.38114
#
# [75337 rows x 5 columns]

# %%
#reordering columns using iloc
df_ = final_df.iloc[:, [0,1,3,2,4]]
print("Reordered Dataset:")
df_
# Out:
# Reordered Dataset:
#       Protein_x Amino_Acid_x specific_Protein_aa sift_Score foldX_Score
# 0        A5A607         K60Q         A5A607_K60Q   0.197799      0.5171
# 1        A5A607         Y56C         A5A607_Y56C    0.17497      0.7287
# 2        A5A607         Y56S         A5A607_Y56S   0.415581     0.84212
# 3        P00350        A117S        P00350_A117S   0.401519    -0.09854
# 4        P00350        A117T        P00350_A117T   0.282769     0.92352
# ...         ...          ...                 ...        ...         ...
# 75332    Q93K97        S190P        Q93K97_S190P    0.01768    -1.77861
# 75333    Q93K97        T124I        Q93K97_T124I   0.169846   -0.973832
# 75334    Q93K97         T23I         Q93K97_T23I   0.094208   -0.242378
# 75335    Q93K97        V145L        Q93K97_V145L        1.0   -0.249012
# 75336    Q93K97         V49I         Q93K97_V49I   0.740893    -0.38114
#
# [75337 rows x 5 columns]

# %%
#Using the criteria above, Find all mutations that have a SIFT score below 0.05 and FoldX Score above 2
 #(i.e: Mutations that affect both structure and function)
#Study the amino acid substitution nomenclature

mutations_df = df_.query('sift_Score<0.05 and foldX_Score>2')
print("Dataset that shows the mutations that affect both structure and function:")
mutations_df
# Out:
# Dataset that shows the mutations that affect both structure and function:
#       Protein_x Amino_Acid_x specific_Protein_aa sift_Score foldX_Score
# 82       P00350         G48C         P00350_G48C   0.031864     2.25298
# 100      P00350        L115F        P00350_L115F   0.028872     3.12672
# 102      P00350        L204F        P00350_L204F    0.00956     3.31406
# 103      P00350        L208R        P00350_L208R   0.027592      4.3869
# 209      P00363        I150F        P00363_I150F   0.048688     9.18496
# ...         ...          ...                 ...        ...         ...
# 75267    Q6BEX0        V211F        Q6BEX0_V211F   0.013334     12.8114
# 75277    Q6BF16         A97V         Q6BF16_A97V   0.039486     2.52316
# 75281    Q6BF16         G80S         Q6BF16_G80S        0.0     4.58514
# 75311    Q6BF17        G250C        Q6BF17_G250C   0.028912     3.59832
# 75315    Q6BF17        H298N        Q6BF17_H298N   0.014758     2.57016
#
# [5261 rows x 5 columns]

# %%
#Investigate for the amino acid that has the most functional and structural impact

#Hint: Using the amino acid column, find a way to select the first amino acid.
#Extract the first amino acid from the amino acid column and store it in a new column
mutations_df['First_Amino_Acid'] = mutations_df['Amino_Acid_x'].str[0]
mutations_df
# Out:
# <ipython-input-24-f8be2cf08df8>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Protein_x Amino_Acid_x specific_Protein_aa sift_Score foldX_Score  \
# 82       P00350         G48C         P00350_G48C   0.031864     2.25298
# 100      P00350        L115F        P00350_L115F   0.028872     3.12672
# 102      P00350        L204F        P00350_L204F    0.00956     3.31406
# 103      P00350        L208R        P00350_L208R   0.027592      4.3869
# 209      P00363        I150F        P00363_I150F   0.048688     9.18496
# ...         ...          ...                 ...        ...         ...
# 75267    Q6BEX0        V211F        Q6BEX0_V211F   0.013334     12.8114
# ...

# %%
# calculate the frequency of each first amino acid to identify the most frequent one
#generate a frequency table for all the amino acids
amino_acid_frequency = mutations_df['First_Amino_Acid'].value_counts()
amino_acid_frequency
# Out:
# First_Amino_Acid
# G    1307
# L     739
# A     640
# P     470
# V     380
# R     227
# I     212
# Y     172
# D     171
# F     169
# S     158
# T     126
# W     108
# M      87
# C      74
# N      60
# E      50
# H      47
# Q      40
# K      24
# Name: count, dtype: int64

# %%
print(f"The amino acid that has the most functional and structural impact is {amino_acid_frequency.index[0]}, which stands for Glycine.")
# Out:
# The amino acid that has the most functional and structural impact is G, which stands for Glycine.

# %%
#Using the amino frequency table above,
#generate a barplot and pie chart to represent the frequency of the amino acids.

#This is the piechart

fig = px.pie(labels = amino_acid_frequency.index, values = amino_acid_frequency.values,
             title = "Amino Acids Frequency",
             names = amino_acid_frequency.index,
             hole = 0.5,
             color = amino_acid_frequency.index,

             color_discrete_sequence=px.colors.sequential.RdBu)



fig.update_traces(textposition = 'outside', textinfo = 'percent + label')

fig.update_layout(
    autosize=False,
    width=700,
    height=700
)



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#This is the barplot

fig = px.bar(x = amino_acid_frequency.index,
        y = amino_acid_frequency.values,
        color = amino_acid_frequency.values,
        color_continuous_scale='Bluered_r',
             title = "Amino Acids Frequency",
             labels = {
                 "x": "Amino Acid",
                 "y": "Frequency"
             }
             )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **About Glycine**
#
# Glycine is a non-essential aminoacid that is found primarily in gelatin and silk fibroin and used therapeutically as a nutrient. It has hepatoprotective properties, too. It is also a fast inhibitory neurotransmitter. It has a simple and achiral structure, with a hydrogen atom as its side chain.
#
# References
# https://pubchem.ncbi.nlm.nih.gov/compound/Glycine

# %% [markdown]
# **About high occurence amino acids**
#
# High occurrence amino acids suggest that the amino acid is at a critical position and that mutations at these positions more likely affect structure and functions. Also, looking at the specific amino acids, we can find mostly non-polar once like alanine, leucine, valine and phenylalanine, which are hydrophobic and form interactions within the protein's hydrophobic core, thus stabilising the structure. Also, alanine and leucine are known to form alpha helices.
